# %%
import sys
import os

# Add the root directory to sys.path
sys.path.append(os.path.abspath(".."))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from dynamical_systems.mass_spring_damper_system import MassSpringDamperEnv

import numpy as np
import pygame
import matplotlib.pyplot as plt

# Example Nonlinear
if __name__ == "__main__":
    env = MassSpringDamperEnv(nlin=True)
    obs = env.reset()
    save = []
    clock = pygame.time.Clock()
    for _ in range(500):  # Run 10 steps
        action = np.array(2)  # Example action (constant force of 0.1)
        obs, reward, done, _ = env.step(action)
        save.append(obs)
        env.render()
        clock.tick(400)

env.close()
plt.plot(save)
plt.show()

# %%
from mass_spring_damper_system import MassSpringDamperEnv

import numpy as np
import pygame
import matplotlib.pyplot as plt

# Example Linear
if __name__ == "__main__":
    env = MassSpringDamperEnv()
    obs = env.reset()
    save = []
    clock = pygame.time.Clock()
    for _ in range(500):  # Run 10 steps
        action = np.array(2)  # Example action (constant force of 0.1)
        obs,reward, done, _ = env.step(action)
        save.append(obs)
        env.render()
        clock.tick(400)

env.close()
plt.plot(save)
plt.show()
